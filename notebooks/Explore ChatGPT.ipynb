# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd


pd.options.display.max_colwidth = 1000

df = pd.read_csv("../data/runs/sample_dev_df_chatgpt.csv")

del df["body"]
print(df.columns)
df.sample(5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Index(['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'CALLS', 'WOMEN',
#        'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE',
#        'CRIMINAL', 'num_hatred', 'text_label', 'pred_cot', 'prompt',
#        'PRED_WOMEN', 'PRED_LGBTI', 'PRED_RACISM', 'PRED_CLASS',
#        'PRED_POLITICS', 'PRED_DISABLED', 'PRED_APPEARANCE', 'PRED_CRIMINAL',
#        'PRED_HATEFUL'],
#       dtype='object')
#          id  \
# 436  389500
# 195  382065
# 116  363527
# 72   342752
# 579  399235
#
#                                                                                                               title  \
# 436                                  Ginés González García: "Le tengo mucho miedo al verano, el riesgo va a seguir"
# 195  La muerte de su esposa, de dos de sus hijos y una delicada cirugía cerebral: las tragedias que vivió Joe Biden
# 116                       El summum de la grieta: Cristina Kirchner tiene 0% de imagen positiva entre los macristas
# 72                                     Coronavirus: las terribles imágenes del mercado donde se originó la pandemia
# 579           Dady Brieva: "Los del campo tampoco van a ser muy felices cuando la muchachada salga a buscar comida"
#
#                                                                                                                                                                                                                                    text  \
# 436                                                                                                                                                                 @usuario Y a nosotros nos preocupa la incompetencia y la ineptitud.
# 195                                                                                                                                                                  @usuario Quiere dar lástima para buscar votos... !!! Viva TRUMP...
# 116                                                                                                                                                                                                              @usuario ¡Que novedad!
# 72   @usuario Loci dejen de joder con lo de la sopa de murcielago..¡¡ Este virus es made in china por quilombos que en nuestra puta vida nos vamos a enterar..¡¡ Ni olvido ni perdón muerte al gobierno chino por lo que nos hicieron..
# 579                                         @usuario @usuario Los muchachos también pueden pasar primero por tu depto en puerto Madero cuando salgan a buscar comida. No aprendes más HDP. Mereces ser cancelado. #GancelenADabyBrieva.
#
#                                                                                                                               context_tweet  \
# 436                                  Ginés González García: "Le tengo mucho miedo al verano, el riesgo va a seguir" https://t.co/qDSNBVD3ir
# 195  La muerte de su esposa, de dos de sus hijos y una delicada cirugía cerebral: las tragedias que vivió Joe Biden https://t.co/wk94Gvcfd6
# 116                       El summum de la grieta: Cristina Kirchner tiene 0% de imagen positiva entre los macristas https://t.co/0VCpRP8N9M
# 72                                     Coronavirus: las terribles imágenes del mercado donde se originó la pandemia https://t.co/Sy9BvJATax
# 579           Dady Brieva: “Los del campo tampoco van a ser muy felices cuando la muchachada salga a buscar comida” https://t.co/wCIIsHnKqR
#
#      HATEFUL  CALLS  WOMEN  LGBTI  RACISM  CLASS  ...  \
# 436        0      0      0      0       0      0  ...
# 195        0      0      0      0       0      0  ...
# 116        0      0      0      0       0      0  ...
# 72         1      1      0      0       1      0  ...
# 579        0      0      0      0       0      0  ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       prompt  \
# 436  Determinar si el siguiente texto, correspondiente a un tweet y presentado con un contexto, contiene discurso de odio. Entendemos que hay discurso de odio si tiene declaraciones de carácter intenso y/o irracional de rechazo, enemistad o aborrecimiento contra un individuo o contra un grupo, siendo estos objetivos de las expresiones por poseer una característica protegida. Las características protegidas que contemplamos son:\n\n- mujer: hace referencia a mujeres o al movimiento feminista.\n- lgbti: hace referencia a gays, lesbianas, transexuales y otras identidades de género.\n- racismo: hace referencia a inmigrantes, xenofobia, o a pueblos aborígenes.\n- clase: hace referencia a personas de bajos recursos o motivos de clase.\n\nLos tweets están escritos en español rioplatense, y dentro del contexto cultural de Argentina. Responder una o varias de las características separadas por coma, o bien "nada" si no hay discurso de odio. Pensar y justificar paso a paso la respuesta antes de res...
# 195  Determinar si el siguiente texto, correspondiente a un tweet y presentado con un contexto, contiene discurso de odio. Entendemos que hay discurso de odio si tiene declaraciones de carácter intenso y/o irracional de rechazo, enemistad o aborrecimiento contra un individuo o contra un grupo, siendo estos objetivos de las expresiones por poseer una característica protegida. Las características protegidas que contemplamos son:\n\n- mujer: hace referencia a mujeres o al movimiento feminista.\n- lgbti: hace referencia a gays, lesbianas, transexuales y otras identidades de género.\n- racismo: hace referencia a inmigrantes, xenofobia, o a pueblos aborígenes.\n- clase: hace referencia a personas de bajos recursos o motivos de clase.\n\nLos tweets están escritos en español rioplatense, y dentro del contexto cultural de Argentina. Responder una o varias de las características separadas por coma, o bien "nada" si no hay discurso de odio. Pensar y justificar paso a paso la respuesta antes de res...
# 116  Determinar si el siguiente texto, correspondiente a un tweet y presentado con un contexto, contiene discurso de odio. Entendemos que hay discurso de odio si tiene declaraciones de carácter intenso y/o irracional de rechazo, enemistad o aborrecimiento contra un individuo o contra un grupo, siendo estos objetivos de las expresiones por poseer una característica protegida. Las características protegidas que contemplamos son:\n\n- mujer: hace referencia a mujeres o al movimiento feminista.\n- lgbti: hace referencia a gays, lesbianas, transexuales y otras identidades de género.\n- racismo: hace referencia a inmigrantes, xenofobia, o a pueblos aborígenes.\n- clase: hace referencia a personas de bajos recursos o motivos de clase.\n\nLos tweets están escritos en español rioplatense, y dentro del contexto cultural de Argentina. Responder una o varias de las características separadas por coma, o bien "nada" si no hay discurso de odio. Pensar y justificar paso a paso la respuesta antes de res...
# 72   Determinar si el siguiente texto, correspondiente a un tweet y presentado con un contexto, contiene discurso de odio. Entendemos que hay discurso de odio si tiene declaraciones de carácter intenso y/o irracional de rechazo, enemistad o aborrecimiento contra un individuo o contra un grupo, siendo estos objetivos de las expresiones por poseer una característica protegida. Las características protegidas que contemplamos son:\n\n- mujer: hace referencia a mujeres o al movimiento feminista.\n- lgbti: hace referencia a gays, lesbianas, transexuales y otras identidades de género.\n- racismo: hace referencia a inmigrantes, xenofobia, o a pueblos aborígenes.\n- clase: hace referencia a personas de bajos recursos o motivos de clase.\n\nLos tweets están escritos en español rioplatense, y dentro del contexto cultural de Argentina. Responder una o varias de las características separadas por coma, o bien "nada" si no hay discurso de odio. Pensar y justificar paso a paso la respuesta antes de res...
# 579  Determinar si el siguiente texto, correspondiente a un tweet y presentado con un contexto, contiene discurso de odio. Entendemos que hay discurso de odio si tiene declaraciones de carácter intenso y/o irracional de rechazo, enemistad o aborrecimiento contra un individuo o contra un grupo, siendo estos objetivos de las expresiones por poseer una característica protegida. Las características protegidas que contemplamos son:\n\n- mujer: hace referencia a mujeres o al movimiento feminista.\n- lgbti: hace referencia a gays, lesbianas, transexuales y otras identidades de género.\n- racismo: hace referencia a inmigrantes, xenofobia, o a pueblos aborígenes.\n- clase: hace referencia a personas de bajos recursos o motivos de clase.\n\nLos tweets están escritos en español rioplatense, y dentro del contexto cultural de Argentina. Responder una o varias de las características separadas por coma, o bien "nada" si no hay discurso de odio. Pensar y justificar paso a paso la respuesta antes de res...
#
#      PRED_WOMEN  PRED_LGBTI  PRED_RACISM  PRED_CLASS PRED_POLITICS  \
# 436           0           0            0           0             0
# 195           0           0            0           0             0
# 116           0           0            0           0             0
# 72            0           0            1           0             0
# 579           0           0            0           0             0
#
#     PRED_DISABLED PRED_APPEARANCE  PRED_CRIMINAL  PRED_HATEFUL
# 436             0               0              0             0
# 195             0               0              0             0
# 116             0               0              0             0
# 72              0               0              0             1
# 579             0               0              0             0
#
# [5 rows x 27 columns]

# %%
df.sample(10)[["title", "text",  "pred_cot"]]
# Out:
#                                                                                                                                 title  \
# 681                 Alberto Fernández recibió a Hugo Moyano en Olivos: hablaron sobre paritarias, empleo y la recolección de residuos
# 525          Alberto Fernández: "La pandemia es una oportunidad, hay que ocuparse de los argentinos que la meritocracia dejó de lado"
# 7                                                                                  ¿Se puede ser feminista y llorar a Diego Maradona?
# 12                          En Salta mandaron a un abusador a la casa porque se llovía su calabozo: vive al lado de la nena que atacó
# 510                                                         Un grupo de gorilas en un zoológico en California se contagió de COVID-19
# 2                   "Se terminó, a salir a la calle": detuvieron a un hombre que se grabó llamando a romper la cuarentena obligatoria
# 572  Denuncian a Verónica Ojeda y el jefe de gabinete de Sergio Berni por violar la cuarentena y agredir a oficiales de la bonaerense
# 73                                     Un jubilado se enfrentó a tres ladrones que entraron a su casa y mató a balazos a uno de ellos
# 544                          El Ejército de Paraguay mata a dos guerrilleras en un campamento del grupo armado EPP: serían argentinas
# 652                          Tres extranjeros incumplían la cuarentena total y agredieron a los policías que quisieron identificarlos
#
#                                                                                                                                                                                                                                                                                                 text  \
# 681                                                                                                                                               @usuario Este tipo quiere contagiarse y morirse , ya tiro el poncho , no perdón tiro la toalla , y se nos viene la yegua ahí a comprar pasajes ...
# 525                                                                                                                            @usuario @usuario Esta es una de las afirmaciones mas graves e ignorantes que he escuchado en 37 años de democracia. Muy dañina. Hipotecando el futuro. Irresponsable
# 7                                                                                                                                                                                                                                                                    @usuario Ustedes son una mierda
# 12                                                                                                                                                                                                                                                                          @usuario @usuario Basura
# 510                                                                                                                                                                                                                                                   @usuario Un ejemplo local: el Dr Nelson Castro
# 2                                                                                                                                                                                                                                                                           @usuario Flor de imbécil
# 572  @usuario Y los que deben hacer lo mismo!! Por eso no podemos salir de esta cuarenterna maldita! El presidente @usuario  habla de responsabilidad individual ,de cuidarnos y respetar la vida. Parece que a muchos les cuesta entender o les importa muy poco el otro. #UsaCubrebocas #COVID19 🙏
# 73                                                                                                                                                                    @usuario Si este es el país de los ladrones. Ellos mandan y marcan las reglas de juego. El q labura y cuida lo suyo es un Gil.
# 544                                                                                                                                                                                                                                                                      @usuario Bien muertas están
# 652                                                                                                                                                                                                                                                                                 @usuario Bolitas
#
#                                                                                                                                                                                                                                                                                                                                         pred_cot
# 681                                                                                                                        El texto contiene insultos hacia Alberto Fernández y Cristina Fernández de Kirchner ("la yegua"), pero no presenta un discurso de odio dirigido hacia ninguna característica protegida. La respuesta final es "nada".
# 525                                                                                                                                                       El texto contiene críticas severas hacia la afirmación de Alberto Fernández, pero no incluye comentarios de odio hacia ninguna característica protegida. La respuesta final es "nada".
# 7                                                                                                                                                                                El texto contiene un insulto general ("una mierda") pero no menciona ninguna característica protegida en particular, por lo tanto la respuesta final es "nada".
# 12                                                                                                                                                                                                 El texto no hace referencia a ninguna característica protegida en particular, solo utiliza un insulto genérico. La respuesta final es "nada".
# 510                                                                                                                                                                                                                           La respuesta es "nada", ya que el texto no contiene discurso de odio ni menciona ninguna característica protegida.
# 2                                                                                                                                                                                       El texto insulta al hombre llamándolo "imbécil", pero no contiene discurso de odio hacia ninguna característica protegida. La respuesta final es "nada".
# 572                                                      El texto contiene un reclamo por el comportamiento de Verónica Ojeda y el jefe de gabinete de Sergio Berni en relación a la violación de la cuarentena, y hace una crítica a quienes no respetan las medidas de prevención. No contiene discurso de odio. La respuesta final es "nada".
# 73   El texto alude a la situación de inseguridad en el país, mencionando a los ladrones como quienes mandan y marcan las reglas. También desprecia a quienes trabajan y cuidan lo suyo llamándolos "Gil". A pesar de ser un comentario negativo, no contiene discurso de odio hacia una característica protegida. La respuesta final es "nada".
# 544                                                                                                                                                                                  El texto celebra la muerte de las guerrilleras armado, sin hacer referencia a ninguna característica protegida en particular. La respuesta final es "nada".
# 652                                                                                                             El texto utiliza un término despectivo para referirse a personas extranjeras, en este caso provenientes de Bolivia. Esto implica un discurso de odio relacionado con la xenofobia, por lo tanto la respuesta final es "racismo".

# %%
from rioplatense_hs.preprocessing import labels
from sklearn.metrics import classification_report

reduced_labels = labels[:4]
pred_labels = [f"PRED_{label}" for label in reduced_labels]

classification_report(df[reduced_labels], df[pred_labels], target_names=reduced_labels, output_dict=True)
# Out:
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'WOMEN': {'precision': 0.3333333333333333,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3333333333333333,
#   'support': 21.0},
#  'LGBTI': {'precision': 0.4666666666666667,
#   'recall': 0.5384615384615384,
#   'f1-score': 0.5,
#   'support': 13.0},
#  'RACISM': {'precision': 0.5111111111111111,
#   'recall': 0.575,
#   'f1-score': 0.5411764705882353,
#   'support': 40.0},
#  'CLASS': {'precision': 0.20833333333333334,
#   'recall': 0.5,
#   'f1-score': 0.29411764705882354,
#   'support': 10.0},
#  'micro avg': {'precision': 0.4,
#   'recall': 0.5,
#   'f1-score': 0.4444444444444445,
#   'support': 84.0},
#  'macro avg': {'precision': 0.3798611111111111,
#   'recall': 0.48669871794871794,
#   'f1-score': 0.41715686274509806,
#   'support': 84.0},
#  'weighted avg': {'precision': 0.4237433862433862,
#   'recall': 0.5,
#   'f1-score': 0.4534313725490195,
#   'support': 84.0},
#  'samples avg': {'precision': 0.056428571428571425,
#   'recall': 0.056190476190476187,
#   'f1-score': 0.05547619047619047,
#   'support': 84.0}}
