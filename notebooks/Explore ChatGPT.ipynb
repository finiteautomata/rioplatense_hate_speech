# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd


pd.options.display.max_colwidth = 1000

df = pd.read_csv("../data/runs/sample_dev_df_chatgpt.csv")

del df["body"]
del df["prompt"]
print(df.columns)
df.sample(5)
# Out:
# Index(['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'CALLS', 'WOMEN',
#        'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE',
#        'CRIMINAL', 'num_hatred', 'text_label', 'pred_cot', 'PRED_WOMEN',
#        'PRED_LGBTI', 'PRED_RACISM', 'PRED_CLASS', 'PRED_POLITICS',
#        'PRED_DISABLED', 'PRED_APPEARANCE', 'PRED_CRIMINAL', 'PRED_HATEFUL'],
#       dtype='object')
#          id  \
# 519  404304
# 472  381019
# 7    407369
# 468  403096
# 166  358248
#
#                                                                                                           title  \
# 519                                       Victor Hugo: "Me siento en una etapa de despedida, queda poco tiempo"
# 472  Sergio Berni: "Por primera vez estamos deteniendo gente sin antecedentes que sale a robar para sobrevivir"
# 7                                                            ¿Se puede ser feminista y llorar a Diego Maradona?
# ...

# %%
df.sample(10)[["title", "text",  "pred_cot"]]
# Out:
#                                                                                                                                                title  \
# 148                                                                   Coronavirus en la Argentina. También se probarán dos vacunas chinas en el país
# 48   Diego Poggi se arrepintió de publicar el doloroso mensaje que le escribió su padre cuando le contó que tenía novio: "Exploté de la peor manera"
# 524                  Alberto Fernández descarta la intervención federal a Formosa y apoya a Insfrán pese a las denuncias por violaciones de los DDHH
# 144                                                            Morena Rial estaba haciendo una transmisión en vivo y comenzó a discutir con su novio
# 39                                                       24 de marzo. Florencia Kirchner recordó a Néstor desde la cuarentena con su madre y su hija
# ...

# %%
df[(df["LGBTI"] > 0) != (df["PRED_LGBTI"] > 0) ][["title", "text",  "pred_cot"]]
# Out:
#                                                                                                                                          title  \
# 85                                              El gobierno porteño adelantó que la nueva cuarentena tendrá una fecha de finalización concreta
# 98   La frase homofóbica de Jair Bolsonaro al hablar del COVID-19 en Brasil: "Todos nos vamos a morir un día, dejen de ser un país de maricas"
# 210                                                  "Me esterilicé, pero no odio a los niños": mi vida dentro del movimiento "libre de hijos"
# 225                         El llanto de Gustavo López tras recuperarse del coronavirus: "La incertidumbre de no saber si salís es muy fuerte"
# 234                                  La impactante historia de la tenista trans que hoy es la N 3 de Argentina en la categoría senior femenino
# ...

# %%
from rioplatense_hs.preprocessing import labels
from sklearn.metrics import classification_report

reduced_labels = labels[:4]
pred_labels = [f"PRED_{label}" for label in reduced_labels]

metrics = classification_report(df[reduced_labels], df[pred_labels], target_names=reduced_labels, output_dict=True)

# pandas show only 3 decimals
pd.options.display.float_format = '{:.3f}'.format

pd.DataFrame(metrics).T
# Out:
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score  support
# WOMEN             0.333   0.238     0.278   21.000
# LGBTI             0.357   0.385     0.370   13.000
# RACISM            0.471   0.600     0.527   40.000
# CLASS             0.286   0.800     0.421   10.000
# ...
