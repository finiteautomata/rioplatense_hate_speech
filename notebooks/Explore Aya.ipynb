# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd


pd.options.display.max_colwidth = 1000

df = pd.read_csv("../data/runs/test_01_aya.csv")


df["error"].sum()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 622

# %%
df.sample(10)[["title", "text",  "pred_cot"]]
# Out:
#                                                                                                                                title  \
# 846                               Alarma en China: más de 3000 personas se enfermaron tras la fuga de una bacteria de un laboratorio
# 265                                 Ginés González García explicó por qué el Gobierno no llegó a un acuerdo con Pfizer por la vacuna
# 1008          Ivana Nadal se cansó de que la criticaran y sorprendió con su respuesta: "Gracias a Dios a fin de año me voy del país"
# 606   Vive con sus dos novios y atiende "la policlínica" del amor libre: 5 preguntas para abrir una relación y sobrevivir al intento
# 852                                              Desde este miércoles, los centros de diálisis no admitirán nuevos pacientes de PAMI
# 357                                   Rosario: para sacar una licencia de conducir habrá que hacer un curso de perspectiva de género
# ...

# %%
df[df["error"]].sample(10)[["title", "text", "text_label", "pred_cot",]]
# Out:
#                                                                                                                         title  \
# 59                                      El difícil presente de Mirta Wons: "No tengo ahorros, los actores estamos en la lona"
# 62                   Guillermo Moreno: "Es una barbaridad cerrar las villas, el peronismo es amor, ¿qué hubiese dicho Evita?"
# 66                       Coronavirus en Argentina: 341 presos bonaerenses inician huelga de hambre y piden "irse a sus casas"
# 93                                              Pablo Moyano amenaza con un paro de recolectores en la Ciudad de Buenos Aires
# 49                                                                  ¿More Rial cuestionó las habilidades de su ex en la cama?
# 0   Coronavirus: un diario inglés asegura que los mercados chinos siguen vendiendo murciélagos y carne de animales domésticos
# ...
