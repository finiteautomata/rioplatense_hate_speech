# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd


pd.options.display.max_colwidth = 1000

df = pd.read_csv("../data/runs/test_03_mixtral_bnb4b.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df.sample(10)[["title", "text", "pred_cot"]]
# Out:
#                                                                                                                                                                   title  \
# 882                                                                                            La princesa Amalia es gorda: se puede decir pero ¿por qué es un insulto?
# 472                                                                                              Quién es Brenda Madrid, la jueza suplente que sobreseyó a Pablo Moyano
# 976  Cristina Kirchner se presentó en los tribunales de Lomas de Zamora: fue citada como testigo en la causa por el presunto espionaje ilegal realizado por el macrismo
# 445                                                                             China alertó sobre brote de peste bubónica pero la OMS no lo considera de "alto riesgo"
# ...

# %%
df[df["error"]].sample(5)[["title", "text", "pred_cot",]]
# Out:
#                                                                                                                                             title  \
# 331  Coronavirus: Alberto Fernández advirtió que, "si el relajamiento sigue, las fuerzas de seguridad saldrán a la calle para disipar a la gente"
# 924                                 La otra batalla mundial, el otro enemigo invisible: "La violencia contra las mujeres es pandemia hace siglos"
# 755                                                                      El reclamo de Dady Brieva al Presidente: "Sí o sí vamos a ser Venezuela"
# 526                                                        "Dios es formoseño". Así explicó un ministro por qué su provincia no tiene coronavirus
# 811                                         Mara Gómez cumple su sueño: será la primera futbolista transgénero en el torneo profesional argentino
#
# ...

# %%
from rioplatense_hs.preprocessing import labels
from sklearn.metrics import classification_report

reduced_labels = labels[:4]
pred_labels = [f"PRED_{label}" for label in reduced_labels]

ret = classification_report(df[reduced_labels], df[pred_labels], target_names=reduced_labels, output_dict=True)

pd.DataFrame(ret).T
# Out:
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jmperez/projects/rioplatense_hate_speech/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score  support
# WOMEN          0.086538  0.600000  0.151261     15.0
# LGBTI          0.404762  0.894737  0.557377     19.0
# RACISM         0.525000  0.736842  0.613139     57.0
# CLASS          0.078125  0.294118  0.123457     17.0
# ...
