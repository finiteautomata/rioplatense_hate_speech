# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd


pd.options.display.max_colwidth = 1000

df = pd.read_csv("../data/sample_100_mixtral_gptq_32g.csv")

old_df = pd.read_csv("../data/sample_100_mixtral.csv")



df["other_cot"] = old_df["pred_cot"]

# %%
df.sample(10)[["title", "text", "text_label", "pred_cot", "other_cot"]]
# Out:
#                                                                                                                                                    title  \
# 32  Luis Brandoni cruzó a Ricardo Alfonsín por sus críticas a la marcha: "No está en el centro de sus convicciones, de lo que ha mamado desde que nació"
# 18                               Coronavirus: con un piquete fronterizo, bolivianos piden controles sanitarios para los argentinos que entran a ese país
# 12                                             En Salta mandaron a un abusador a la casa porque se llovía su calabozo: vive al lado de la nena que atacó
# 91                                         Pandemia y protestas por la violencia policial: dos crisis sacuden a Estados Unidos, según The New York Times
# 98             La frase homofóbica de Jair Bolsonaro al hablar del COVID-19 en Brasil: "Todos nos vamos a morir un día, dejen de ser un país de maricas"
# ...

# %%
df[df["error"]].sample(10)[["title", "text", "text_label", "pred_cot",]]
# Out:
#                                                                                                                         title  \
# 59                                      El difícil presente de Mirta Wons: "No tengo ahorros, los actores estamos en la lona"
# 62                   Guillermo Moreno: "Es una barbaridad cerrar las villas, el peronismo es amor, ¿qué hubiese dicho Evita?"
# 66                       Coronavirus en Argentina: 341 presos bonaerenses inician huelga de hambre y piden "irse a sus casas"
# 93                                              Pablo Moyano amenaza con un paro de recolectores en la Ciudad de Buenos Aires
# 49                                                                  ¿More Rial cuestionó las habilidades de su ex en la cama?
# 0   Coronavirus: un diario inglés asegura que los mercados chinos siguen vendiendo murciélagos y carne de animales domésticos
# ...
